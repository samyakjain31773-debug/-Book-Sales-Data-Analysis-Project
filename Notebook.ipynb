# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Impot Csv File

# %%
df= pd.read_csv("Books_Data_Clean.csv")

# %% [markdown]
# df.head()  function is used to display the first 5 rows of a DataFrame

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %% [markdown]
# The `df.describe()` function is used to generate summary statistics of a DataFrame

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %% [markdown]
# The DataFrame `df` will now only contain books published after the year 1900.

# %%
df=df[df["Publishing Year"]>1900]

# %% [markdown]
# The `df.isna().sum()` function is used to count the number of missing (null) values in each column of a DataFrame.

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name              21
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %% [markdown]
# The `df.dropna(subset="Book Name")` function is used to remove rows
# where the "Book Name" column contains missing (NaN) values.

# %%
df.dropna(subset="Book Name")
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.dropna(subset="Book Name",inplace = True)

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name               0
# Author                  0
# language_code          47
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1065    False
# 1066    False
# 1067    False
# 1068    False
# 1069    False
# Length: 988, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# index                  988
# Publishing Year        101
# Book Name              987
# Author                 669
# language_code            8
# Author_Rating            4
# Book_average_rating    133
# Book_ratings_count     983
# genre                    4
# gross sales            774
# publisher revenue      570
# sale price             143
# sales rank             818
# Publisher                9
# units sold             470
# dtype: int64

# %%
df = []

# %%
df = pd.DataFrame(df)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Books_Data_Clean.csv")

df["genre"].value_counts().plot(kind="bar")

plt.xlabel("Genre")
plt.ylabel("Number of Books")
plt.title("Number of Books in each Genre")
plt.show()

# %%
type(df.groupby("Author")["Book_average_rating"].mean())
# Out:
# pandas.core.series.Series

# %%
df.groupby("Author")["Book_average_rating"].mean()
# Out:
# Author
# A.A. Milne, Ernest H. Shepard                      4.36
# A.S.A. Harrison                                    3.30
# Abbi Glines                                        4.21
# Adam Johnson                                       4.06
# Adam Mansbach, Ricardo CortÃ©s                     4.26
#                                                    ...
# William Styron                                     4.18
# Yana Toboso, Tomo Kimura                           4.37
# Zadie Smith                                        3.75
# Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi    3.72
# Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯                                  3.80
# Name: Book_average_rating, Length: 735, dtype: float64

# %%
df.groupby("Author")["Book_average_rating"].median()
# Out:
# Author
# A.A. Milne, Ernest H. Shepard                      4.36
# A.S.A. Harrison                                    3.30
# Abbi Glines                                        4.21
# Adam Johnson                                       4.06
# Adam Mansbach, Ricardo CortÃ©s                     4.26
#                                                    ...
# William Styron                                     4.18
# Yana Toboso, Tomo Kimura                           4.37
# Zadie Smith                                        3.75
# Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi    3.72
# Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯                                  3.80
# Name: Book_average_rating, Length: 735, dtype: float64

# %%
df.groupby("Author")["Book_average_rating"].mean().head()
# Out:
# Author
# A.A. Milne, Ernest H. Shepard     4.36
# A.S.A. Harrison                   3.30
# Abbi Glines                       4.21
# Adam Johnson                      4.06
# Adam Mansbach, Ricardo CortÃ©s    4.26
# Name: Book_average_rating, dtype: float64

# %%
df.groupby("Author")["Book_average_rating"].mean().tail()
# Out:
# Author
# William Styron                                     4.18
# Yana Toboso, Tomo Kimura                           4.37
# Zadie Smith                                        3.75
# Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi    3.72
# Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯                                  3.80
# Name: Book_average_rating, dtype: float64

# %%
df.groupby("Author")["Book_average_rating"].mean().sort_values(ascending=False)
# Out:
# Author
# Bill Watterson                  4.650
# Bill Watterson, G.B. Trudeau    4.610
# J.R.R. Tolkien                  4.590
# George R.R. Martin              4.560
# Sarah J. Maas                   4.526
#                                 ...
# Audrey Niffenegger              3.230
# Herman Koch, Sam Garrett        3.220
# P.D. James                      3.210
# Stephen Crane                   3.210
# Sue Monk Kidd                   3.100
# Name: Book_average_rating, Length: 735, dtype: float64

# %%
print(df.columns)
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
sns.boxplot(x="genre", y="Book_ratings_count", data=df)

plt.xlabel("Genre")
plt.ylabel("Book Rating Count")
plt.title("Box Plot of Book Rating Counts for Each Genre")

plt.show()

# %%
plt.scatter(df["sale price"],df["units sold"])
plt.xlabel("Sale Price")
plt.ylabel("Units Sold")
plt.title("Scatter Plot of Sale Price Vs Units Sold")
plt.show()

# %%
df["language_code"].value_counts()
# Out:
# language_code
# eng      737
# en-US    234
# en-GB     30
# en-CA      7
# fre        4
# spa        2
# ara        2
# nl         1
# Name: count, dtype: int64

# %%
df["language_code"].value_counts().sort_values(ascending=True)
# Out:
# language_code
# nl         1
# spa        2
# ara        2
# fre        4
# en-CA      7
# en-GB     30
# en-US    234
# eng      737
# Name: count, dtype: int64

# %%
df["language_code"].value_counts().sort_values(ascending= False)
# Out:
# language_code
# eng      737
# en-US    234
# en-GB     30
# en-CA      7
# fre        4
# spa        2
# ara        2
# nl         1
# Name: count, dtype: int64

# %%
language_counts =df["language_code"].value_counts()

# %%
plt.pie(language_counts,labels=language_counts.index,startangle=90,)
plt.title("Language Distribution of Books")
plt.show()

# %%
plt.pie(language_counts, labels=language_counts.index, startangle=90, autopct="%1.1f%%")

plt.title("Language Distribution of Books")
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.groupby("Publisher ")["publisher revenue"].sum()
# Out:
# Publisher
# Amazon Digital Services,  Inc.          148244.178
# Hachette Book Group                     137874.498
# HarperCollins Christian Publishing        2135.670
# HarperCollins Publishers                128478.258
# HarperCollins Publishing                  2830.806
# Macmillan                                32356.236
# Penguin Group (USA) LLC                 213817.482
# Random House LLC                        189585.222
# Simon and Schuster Digital Sales Inc     46988.352
# Name: publisher revenue, dtype: float64

# %%
df.groupby("Publisher ")["publisher revenue"].sum().sort_values(ascending=False)
# Out:
# Publisher
# Penguin Group (USA) LLC                 213817.482
# Random House LLC                        189585.222
# Amazon Digital Services,  Inc.          148244.178
# Hachette Book Group                     137874.498
# HarperCollins Publishers                128478.258
# Simon and Schuster Digital Sales Inc     46988.352
# Macmillan                                32356.236
# HarperCollins Publishing                  2830.806
# HarperCollins Christian Publishing        2135.670
# Name: publisher revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.groupby("Author_Rating")["Book_ratings_count"].mean()
# Out:
# Author_Rating
# Excellent        82905.889503
# Famous           97414.301887
# Intermediate    101946.995200
# Novice           88728.166667
# Name: Book_ratings_count, dtype: float64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].mean().sort_values(ascending=False)
# Out:
# Author_Rating
# Intermediate    101946.995200
# Famous           97414.301887
# Novice           88728.166667
# Excellent        82905.889503
# Name: Book_ratings_count, dtype: float64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].mean().sort_values(ascending=False).head(1)
# Out:
# Author_Rating
# Intermediate    101946.9952
# Name: Book_ratings_count, dtype: float64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].mean().sort_values(ascending=False).max()
# Out:
# 101946.9952

# %%
df.groupby("language_code").size()
# Out:
# language_code
# ara        2
# en-CA      7
# en-GB     30
# en-US    234
# eng      737
# fre        4
# nl         1
# spa        2
# dtype: int64

# %%
df.groupby("language_code").size().sort_values(ascending=False)
# Out:
# language_code
# eng      737
# en-US    234
# en-GB     30
# en-CA      7
# fre        4
# ara        2
# spa        2
# nl         1
# dtype: int64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].mean()
# Out:
# Author_Rating
# Excellent        82905.889503
# Famous           97414.301887
# Intermediate    101946.995200
# Novice           88728.166667
# Name: Book_ratings_count, dtype: float64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].max().sort_values(ascending=False)
# Out:
# Author_Rating
# Famous          206792
# Intermediate    199872
# Excellent       167848
# Novice          155903
# Name: Book_ratings_count, dtype: int64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].median().sort_values(ascending=False)
# Out:
# Author_Rating
# Intermediate    98645.0
# Famous          90574.0
# Excellent       80587.0
# Novice          77446.5
# Name: Book_ratings_count, dtype: float64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].std().sort_values(ascending=False)
# Out:
# Author_Rating
# Famous          34238.288157
# Intermediate    34160.111816
# Novice          32028.938059
# Excellent       20930.833380
# Name: Book_ratings_count, dtype: float64

# %%
df.groupby("Author_Rating")["Book_ratings_count"].var().sort_values(ascending=False)
# Out:
# Author_Rating
# Famous          1.172260e+09
# Intermediate    1.166913e+09
# Novice          1.025853e+09
# Excellent       4.380998e+08
# Name: Book_ratings_count, dtype: float64

# %%
plt.scatter(df["Book_average_rating"],df["Book_ratings_count"])
plt.xlabel("Book Average Rating")
plt.ylabel("Book Ratings Count")
plt.title("Scatter Plot of Book Average Rating VS Book Rating Count")
plt.show()

# %%
total_gross_sales_by_author = df.groupby("Author")["gross sales"].sum()

# %%
total_gross_sales_by_author
# Out:
# Author
# A.A. Milne, Ernest H. Shepard                       214.92
# A.S.A. Harrison                                     784.16
# Abbi Glines                                        2990.16
# Adam Johnson                                        108.90
# Adam Mansbach, Ricardo CortÃ©s                      113.85
#                                                     ...
# William Styron                                      220.89
# Yana Toboso, Tomo Kimura                           1366.86
# Zadie Smith                                         167.31
# Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi    1200.10
# Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯                                  1128.87
# Name: gross sales, Length: 735, dtype: float64

# %%
total_gross_sales_by_author.sort_values(ascending=False)
# Out:
# Author
# Harper Lee              47795.00
# Stephen King            43322.65
# David Sedaris           42323.41
# Charlaine Harris        39453.08
# Laini Taylor            38278.41
#                           ...
# Nathaniel Philbrick       107.91
# Frank Warren              107.91
# Walter M. Miller Jr.      106.92
# Michael Shaara            105.93
# Blake Crouch              105.93
# Name: gross sales, Length: 735, dtype: float64

# %%
total_gross_sales_by_author.sort_values(ascending=False).head(10)
# Out:
# Author
# Harper Lee                47795.00
# Stephen King              43322.65
# David Sedaris             42323.41
# Charlaine Harris          39453.08
# Laini Taylor              38278.41
# Unknown, Seamus Heaney    34160.00
# Sarah Dessen              31034.85
# Colleen Hoover            30882.07
# C.S. Lewis                28972.57
# Brandon Sanderson         28877.45
# Name: gross sales, dtype: float64

# %%
total_gross_sales_by_author.sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel("Author")
plt.ylabel("Total Gross Sales")
plt.title("Total Gross Sales For Each Author")
plt.show()

# %%
total_gross_sales_by_author.sort_values(ascending=False).head(20).plot(kind='bar')
plt.xlabel("Author")
plt.ylabel("Total Gross Sales")
plt.title("Total Gross Sales For Each Author")
plt.show()

# %%
sns.boxplot(x="Author_Rating",y="units sold",data=df)
plt.xlabel("Author Rating")
plt.ylabel("Units Sold")
plt.title("Box Plot of Units sold for Each Author Rating")
plt.show()

# %%
df.groupby("Publishing Year")["units sold"].sum()
# Out:
# Publishing Year
# -560.0      53784
# -441.0        108
# -430.0        308
# -380.0        391
# -300.0       3915
#             ...
#  2012.0    769084
#  2013.0    422449
#  2014.0    182342
#  2015.0    231140
#  2016.0     91276
# Name: units sold, Length: 150, dtype: int64

# %%
df.groupby("Publishing Year")["units sold"].sum().plot(kind="line",marker="o")
plt.xlabel("Publishing Year")
plt.ylabel("Total Units Sold")
plt.title("Total units Sold Over the Years")
plt.show()

# %%
df.groupby("Publishing Year")["units sold"].sum().plot(kind="line",)
plt.xlabel("Publishing Year")
plt.ylabel("Total Units Sold")
plt.title("Total units Sold Over the Years")
plt.show()
